# %% [markdown]
# # DAS Data Compression using Autoencoder
#
# This notebook shows how to do lossy DAS data compression using neural networks (Autoencoder). The original code is from [TensorFlow Compression](https://github.com/tensorflow/compression).

# %% [markdown]
# ## Paper and posts for understanding related theories
#
# 1. [End-to-end Optimized Image Compression](https://arxiv.org/abs/1611.01704)
# 2. [Image Compression Using Autoencoders in Keras](https://blog.paperspace.com/autoencoder-image-compression-keras/)
# 3. [AI-Based Image Compression: The State of the Art](https://towardsdatascience.com/ai-based-image-compression-the-state-of-the-art-fb5aa6042bfa)

# %% [markdown]
# ## TODO
#
# 1. normalize
# 2. tool in scikit-image that will tile images
# 3. creat over lapping data

# %% [markdown]
# ## Setup
#
# Install Tensorflow Compression via `pip`.

# %%
# %%bash
# # Installs the latest version of TFC compatible with the installed TF version.
#
# read MAJOR MINOR <<< "$(pip show tensorflow | perl -p -0777 -e 's/.*Version: (\d+)\.(\d+).*/\1 \2/sg')"
# pip install "tensorflow-compression<$MAJOR.$(($MINOR+1))"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-compression<2.13 in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: scipy~=1.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-compression<2.13) (1.10.1)
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-compression<2.13) (2.12.0)
# Requirement already satisfied: tensorflow-probability~=0.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow-compression<2.13) (0.20.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy~=1.4->tensorflow-compression<2.13) (1.22.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tensorflow-compression<2.13) (0.32.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.15->tensorflow-compression<2.13) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.15->tensorflow-compression<2.13) (2.2.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.15->tensorflow-compression<2.13) (0.1.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tensorflow-compression<2.13) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tensorflow-compression<2.13) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tensorflow-compression<2.13) (3.2.2)

# %% [markdown]
# Import library dependencies.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import tensorflow_compression as tfc
import tensorflow_datasets as tfds

plt.rcParams.update({'font.size': 14})

# %%
import sys
print(sys.version)
# Out:
# 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]

# %% [markdown]
# ## Define the trainer model.
#
# Because the model resembles an autoencoder, and we need to perform a different set of functions during training and inference, the setup is a little different from, say, a classifier.
#
# The training model consists of three parts:
# - the **analysis** (or encoder) transform, converting from the image into a latent space,
# - the **synthesis** (or decoder) transform, converting from the latent space back into image space, and
# - a **prior** and entropy model, modeling the marginal probabilities of the latents.
#
# First, define the transforms:

# %%
def make_analysis_transform(latent_dims):
  """Creates the analysis (encoder) transform."""
  return tf.keras.Sequential([
      tf.keras.layers.Conv2D(20, 5, use_bias=True, strides=2, padding="same", activation="leaky_relu", name="conv_1"),
      tf.keras.layers.Conv2D(50, 5, use_bias=True, strides=2, padding="same", activation="leaky_relu", name="conv_2"),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(500, use_bias=True, activation="leaky_relu", name="fc_1"),
      tf.keras.layers.Dense(latent_dims, use_bias=True, activation=None, name="fc_2"),
  ], name="analysis_transform")


def make_synthesis_transform(patch_size):
  """Creates the synthesis (decoder) transform."""
  if (patch_size // 4) * 4 != patch_size:
    raise ValueError('patch_size must be dividable ny 4!')

  return tf.keras.Sequential([
      tf.keras.layers.Dense(500, use_bias=True, activation="leaky_relu", name="fc_1"),
      tf.keras.layers.Dense(50 * (patch_size//4)**2, use_bias=True, activation="leaky_relu", name="fc_2"),
      tf.keras.layers.Reshape((patch_size//4, patch_size//4, 50)),
      tf.keras.layers.Conv2DTranspose(20, 5, use_bias=True, strides=2, padding="same", activation="leaky_relu", name="conv_1"),
      tf.keras.layers.Conv2DTranspose(1, 5, use_bias=True, strides=2, padding="same", activation="leaky_relu", name="conv_2"),
  ], name="synthesis_transform")

# %% [markdown]
# daThe trainer holds an instance of both transforms, as well as the parameters of the prior.
#
# Its `call` method is set up to compute:
# - **rate**, an estimate of the number of bits needed to represent the batch of digits, and
# - **distortion**, the mean absolute difference between the pixels of the original data patch and their reconstructions.

# %%
class DASCompressionTrainer(tf.keras.Model):
  """Model that trains a compressor/decompressor for DAS data."""

  def __init__(self, latent_dims, patch_size):
    super().__init__()
    self.analysis_transform = make_analysis_transform(latent_dims)
    self.synthesis_transform = make_synthesis_transform(patch_size)
    self.prior_log_scales = tf.Variable(tf.zeros((latent_dims,)))

  @property
  def prior(self):
    return tfc.NoisyLogistic(loc=0., scale=tf.exp(self.prior_log_scales))

  def call(self, x, training):
    """Computes rate and distortion losses."""
    # Ensure inputs are floats in the range (0, 1).

    # Note: since x is devided by 255, we need mutiply the 
    # original data by 255 to keep consistency in data preparation
    x = tf.cast(x, self.compute_dtype) / 255.

    # Compute latent space representation y, perturb it and model its entropy,
    # then compute the reconstructed pixel-level representation x_hat.
    y = self.analysis_transform(x)
    entropy_model = tfc.ContinuousBatchedEntropyModel(self.prior, coding_rank=1, compression=False)
    y_tilde, rate = entropy_model(y, training=training)
    x_tilde = self.synthesis_transform(y_tilde)

    # Average number of bits per MNIST digit.
    rate = tf.reduce_mean(rate)

    # Mean absolute difference across pixels.
    distortion = tf.reduce_mean(abs(x - x_tilde))

    return dict(rate=rate, distortion=distortion)

# %% [markdown]
# Train the model.
# We compile the trainer in a way that it optimizes the rate–distortion Lagrangian, that is, a sum of rate and distortion, where one of the terms is weighted by Lagrange parameter  𝜆 .
#
# This loss function affects the different parts of the model differently:
#
# The analysis transform is trained to produce a latent representation that achieves the desired trade-off between rate and distortion.
# The synthesis transform is trained to minimize distortion, given the latent representation.
# The parameters of the prior are trained to minimize the rate given the latent representation. This is identical to fitting the prior to the marginal distribution of latents in a maximum likelihood sense.

# %%
def pass_through_loss(_, x):
  # Since rate and distortion are unsupervised, the loss doesn't need a target.
  return x


def add_rd_targets(image, label):
  # Training is unsupervised, so labels aren't necessary here. However, we
  # need to add "dummy" targets for rate and distortion.
  return image, dict(rate=0., distortion=0.)


def train_das_model(training_dataset,    # training dataset
                    validation_dataset,  # validation dataset
                    lmbda=2000,          # weight for rate–distortion Lagrangian
                    latent_dims=50,      # layers in latent space
                    patch_size = 28,     # patch size of the image, must be dividable by 4
                    epochs=15,           # epoch
                    batch_size=128,      # batch size
                    learning_rate=1e-3,  # learning rate
                    validation_freq=1,   # validation freq
                    ):

  trainer = DASCompressionTrainer(latent_dims, patch_size)
  trainer.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
      # Just pass through rate and distortion as losses/metrics.
      loss=dict(rate=pass_through_loss, distortion=pass_through_loss),
      metrics=dict(rate=pass_through_loss, distortion=pass_through_loss),
      loss_weights=dict(rate=1., distortion=lmbda),)

  history = trainer.fit(training_dataset.map(add_rd_targets).batch(batch_size).prefetch(8),
      epochs=epochs,
      validation_data=validation_dataset.map(add_rd_targets).batch(batch_size).cache(),
      validation_freq=validation_freq,
      verbose=1,)

  return trainer, history

# %% [markdown]
# ## Tools for preparing DAS data

# %%
def extract_image_patches(DAS_data, patch_size):
  ''' Divide the DAS data (channels by time samples) into small
      patches with the size of patch_size

        Parameters
        ----------
        DAS_data : numpy array (channels by time samples)
        patch_size : int, size of the patch
        
        Returns
        -------
        patches : list of patches
        factors : list of factors used in patch normalization
  '''

  height, width, = DAS_data.shape

  patches = []
  factors = []
  for y in range(0, height - patch_size + 1, patch_size):
    for x in range(0, width - patch_size + 1, patch_size):

      # extract the patch
      patch = DAS_data[y:y + patch_size, x:x + patch_size]
        
      # post-process the patch
      patch = patch.reshape(patch_size, patch_size, 1)
      patch.astype(np.float32)

      # normalize the patch by to the scale of 255 (consistent with the code)
      norm_factor = 1.0 / np.max(abs(patch)) * 255
      patch = patch * norm_factor
      patch[patch == np.nan] = 0.0

    
      # append
      factors.append(norm_factor)
      patches.append(patch)

  return patches, factors


def prepare_das_dataset(data_list, train_ratio = 0.8, shuffle = True):
  ''' Split the data into training and validation sets

        Parameters  
        ----------
        data_list : list
            list of data
        train_ratio : float
            ratio of training data
        shuffle: boolean
            shuffle or not
        
        Returns
        -------
        training_dataset : tf.data.Dataset
            training dataset
        validation_dataset : tf.data.Dataset
            validation dataset          
  '''
  
  # Shuffle the data randomly (we can also do this using TensorFlow feature)
  if shuffle == True:
    random.shuffle(data_list)

  # Calculate the split index based on the train_ratio
  split_index = int(len(data_list) * train_ratio)

  # Split the data into training and validation sets
  train_data = data_list[:split_index]
  validation_data = data_list[split_index:]
  
  # Convert the Python lists to TensorFlow tensors
  train_data = tf.convert_to_tensor(train_data, dtype=tf.float32)
  validation_data = tf.convert_to_tensor(validation_data, dtype=tf.float32)

  # Create TensorFlow datasets (the label is the same as the input)
  training_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
  validation_dataset = tf.data.Dataset.from_tensor_slices((validation_data, validation_data))

  return training_dataset, validation_dataset


def reconstruct_image_from_patches(patches, factors, original_shape, patch_size):
    ''' Reconstruct the original image from patches.

        Parameters
        ----------
        patches : list of patches
        original_shape : tuple, shape of the original image (channels, time samples)
        patch_size : int, size of the patch
        factors : list of factors used in patch normalization

        Returns
        -------
        reconstructed_image : numpy array, the reconstructed image
    '''

    height, width = original_shape

    reconstructed_image = np.zeros(original_shape)

    patch_index = 0
    for y in range(0, height - patch_size + 1, patch_size):
        for x in range(0, width - patch_size + 1, patch_size):

            # get the patch
            patch = patches[patch_index]
            patch = np.reshape(patch, (patch_size, patch_size))

            # restore the normalization
            patch = patch / factors[patch_index]
            patch[patch==np.nan] = 0.0

            # put the patch back to where it belongs to
            reconstructed_image[y:y + patch_size, x:x + patch_size] = patch
            patch_index += 1

    return reconstructed_image

# %% [markdown]
# ## Load the preprocessed DAS data from the Google Storate

# %%
# load my google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.cloud import storage
from io import BytesIO

## Approch 1: Load the data from the Google Storage (unfinished and not test, no access)
# client = storage.Client()
# bucket = client.get_bucket("smcity-cs230-das")
# data = []
# for lblob in lblob_pro:
#   blob = bucket.get_blob(lblob)
#   data.append(np.load(BytesIO(blob.download_as_string())))

## Approch 2: copy the data from the Google Storage (unfinished and not test, no access)
# for lblob in lblob_pro:
#    ! gsutil cp gs://{lblob} /content/.


## Approch 3: mannually download to my Macbook and upload here (works for me!!!)

## Approch 4: Mount the Google Drive
# I select several data from my Google Drive, eight DAS sections for training
# file_path = './drive/MyDrive/Training Dataset/'
# file_train = [file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz', \
#              file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-17-56_p10min.npz', \
#              file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-27-56_p10min.npz', \
#              file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-47-56_p10min.npz', \
#              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz', \
#              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-17-56_p10min.npz', \
#              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-37-56_p10min.npz', \
#              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-47-56_p10min.npz'
#              ]

# two DAS section for testing
# file_test = [file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-37-56_p10min.npz', \
#              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-27-56_p10min.npz'     
#             ]

file_path = './drive/MyDrive/Training Dataset/effective_dataset/'
file_train = [file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz', \
              file_path + 'smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-26_T00-37-56_p10min.npz', \
              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz'
             ]

file_test = [
              file_path + 'smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-26_T00-37-56_p10min.npz'    
            ]

# %%
# Load DAS data
data = np.load(file_train[0])

# Retrieve the data and parameters
pdata = data['pdata']
nc = data['nc']
chans = data['chans']
nt = data['nt']
sf = data['sf']
bp = data['band']
date = data['date']

# Print info
print('Data shape: ', pdata.shape)
print('Number of channels: ', nc)
print('Number of chans: ', chans)
print('Number of time samples: ', nt)
print('Sampling frequency: ', sf)
print('Bandpass: ', bp)
print('Date: ', date)

# Plot
pclip = np.percentile(pdata, 99.)
plt.imshow(pdata, cmap='gray', aspect='auto', vmin=-pclip, vmax=pclip)
# Out:
# Data shape:  (3100, 3000)
# Number of channels:  3100
# Number of chans:  [3000 6100]
# Number of time samples:  3000
# Sampling frequency:  5
# Bandpass:  [0.08 2.  ]
# Date:  1666692476

# %%
# Setup parameters
patch_size = 32
train_ratio = 0.8

# Extract image patches (we can join lists together from different data)
patches_all = []
factors_all = []

for i in file_train:
  print('Loading: %s'%(i))

  # Load the data
  pdata = np.load(i)['pdata']

  # Extract patches and normalzation factor
  patches, factors = extract_image_patches(pdata, patch_size)

  # union patches from different data
  patches_all += patches
  factors_all += factors

# Split the data into training and testing dataset
training_dataset, validation_dataset = prepare_das_dataset(patches_all, train_ratio = train_ratio, shuffle = True)

# Print info
print('\n')
print('Number of training data: ', len(training_dataset))
print('Number of validation data: ', len(validation_dataset))
print(training_dataset)
print(validation_dataset)
# Out:
# Loading: ./drive/MyDrive/Training Dataset/effective_dataset/smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz
# Loading: ./drive/MyDrive/Training Dataset/effective_dataset/smcity_sandhill_nc3100_ch3000-6100_nt3000_sf5_bp0.08-2_D2022-10-26_T00-37-56_p10min.npz
# Loading: ./drive/MyDrive/Training Dataset/effective_dataset/smcity_rwc_nc4800_ch37500-42300_nt3000_sf5_bp0.08-2_D2022-10-25_T10-07-56_p10min.npz
#
#
# Number of training data:  25444
# Number of validation data:  6362
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None), TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None))>
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None), TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None))>

# %%
# Check the data visually 
(x, _), = validation_dataset.take(1)
plt.imshow(tf.squeeze(x), cmap = 'seismic')
plt.colorbar()
print(f"Data type: {x.dtype}")
print(f"Shape: {x.shape}")
# Out:
# Data type: <dtype: 'float32'>
# Shape: (32, 32, 1)

# %% [markdown]
# ## Train the model

# %%
trainer, history = train_das_model(
                    training_dataset,          # training dataset
                    validation_dataset,        # validation dataset
                    lmbda=2000,                # weight for rate–distortion Lagrangian
                    latent_dims=100,            # layers in latent space
                    patch_size = patch_size,   # patch size of the image, must be dividable by 4
                    epochs=100,                # epoch
                    batch_size=128,            # batch size
                    learning_rate=1e-3,        # learning rate
                    validation_freq=1,)        # validation freq
# Out:
# Epoch 1/100
# 199/199 [==============================] - ETA: 0s - loss: 498.8847 - distortion_loss: 0.1449 - rate_loss: 209.0192 - distortion_pass_through_loss: 0.1449 - rate_pass_through_loss: 209.0153
# WARNING:absl:Computing quantization offsets using offset heuristic within a tf.function. Ideally, the offset heuristic should only be used to determine offsets once after training. Depending on the prior, estimating the offset might be computationally expensive.
# 199/199 [==============================] - 11s 18ms/step - loss: 498.8847 - distortion_loss: 0.1449 - rate_loss: 209.0192 - distortion_pass_through_loss: 0.1449 - rate_pass_through_loss: 209.0153 - val_loss: 415.1457 - val_distortion_loss: 0.1053 - val_rate_loss: 204.6122 - val_distortion_pass_through_loss: 0.1053 - val_rate_pass_through_loss: 204.6043
# Epoch 2/100
# 199/199 [==============================] - 2s 9ms/step - loss: 398.7330 - distortion_loss: 0.1006 - rate_loss: 197.5038 - distortion_pass_through_loss: 0.1006 - rate_pass_through_loss: 197.4948 - val_loss: 384.1899 - val_distortion_loss: 0.0972 - val_rate_loss: 189.7713 - val_distortion_pass_through_loss: 0.0972 - val_rate_pass_through_loss: 189.7647
# Epoch 3/100
# 199/199 [==============================] - 2s 8ms/step - loss: 373.1949 - distortion_loss: 0.0950 - rate_loss: 183.1743 - distortion_pass_through_loss: 0.0950 - rate_pass_through_loss: 183.1660 - val_loss: 365.3817 - val_distortion_loss: 0.0953 - val_rate_loss: 174.7359 - val_distortion_pass_through_loss: 0.0953 - val_rate_pass_through_loss: 174.7277
# Epoch 4/100
# 199/199 [==============================] - 2s 9ms/step - loss: 356.3719 - distortion_loss: 0.0934 - rate_loss: 169.5323 - distortion_pass_through_loss: 0.0934 - rate_pass_through_loss: 169.5254 - val_loss: 348.2993 - val_distortion_loss: 0.0930 - val_rate_loss: 162.3382 - val_distortion_pass_through_loss: 0.0930 - val_rate_pass_through_loss: 162.3281
# Epoch 5/100
# 199/199 [==============================] - 2s 9ms/step - loss: 341.2227 - distortion_loss: 0.0920 - rate_loss: 157.2737 - distortion_pass_through_loss: 0.0920 - rate_pass_through_loss: 157.2641 - val_loss: 333.6917 - val_distortion_loss: 0.0932 - val_rate_loss: 147.2992 - val_distortion_pass_through_loss: 0.0932 - val_rate_pass_through_loss: 147.2893
# Epoch 6/100
# 199/199 [==============================] - 3s 13ms/step - loss: 327.6630 - distortion_loss: 0.0907 - rate_loss: 146.2242 - distortion_pass_through_loss: 0.0907 - rate_pass_through_loss: 146.2165 - val_loss: 320.6959 - val_distortion_loss: 0.0940 - val_rate_loss: 132.5977 - val_distortion_pass_through_loss: 0.0941 - val_rate_pass_through_loss: 132.5896
# Epoch 7/100
# 199/199 [==============================] - 2s 9ms/step - loss: 314.6638 - distortion_loss: 0.0890 - rate_loss: 136.6643 - distortion_pass_through_loss: 0.0890 - rate_pass_through_loss: 136.6576 - val_loss: 305.5900 - val_distortion_loss: 0.0918 - val_rate_loss: 122.0324 - val_distortion_pass_through_loss: 0.0918 - val_rate_pass_through_loss: 122.0231
# Epoch 8/100
# 199/199 [==============================] - 2s 9ms/step - loss: 303.4202 - distortion_loss: 0.0874 - rate_loss: 128.6124 - distortion_pass_through_loss: 0.0874 - rate_pass_through_loss: 128.6072 - val_loss: 295.3723 - val_distortion_loss: 0.0924 - val_rate_loss: 110.5324 - val_distortion_pass_through_loss: 0.0924 - val_rate_pass_through_loss: 110.5203
# Epoch 9/100
# 199/199 [==============================] - 2s 9ms/step - loss: 294.6562 - distortion_loss: 0.0862 - rate_loss: 122.3105 - distortion_pass_through_loss: 0.0862 - rate_pass_through_loss: 122.3061 - val_loss: 285.4287 - val_distortion_loss: 0.0918 - val_rate_loss: 101.8392 - val_distortion_pass_through_loss: 0.0918 - val_rate_pass_through_loss: 101.8324
# Epoch 10/100
# 199/199 [==============================] - 2s 9ms/step - loss: 287.4162 - distortion_loss: 0.0850 - rate_loss: 117.4283 - distortion_pass_through_loss: 0.0850 - rate_pass_through_loss: 117.4245 - val_loss: 277.7262 - val_distortion_loss: 0.0913 - val_rate_loss: 95.1684 - val_distortion_pass_through_loss: 0.0913 - val_rate_pass_through_loss: 95.1593
# Epoch 11/100
# 199/199 [==============================] - 2s 9ms/step - loss: 282.1489 - distortion_loss: 0.0844 - rate_loss: 113.4335 - distortion_pass_through_loss: 0.0844 - rate_pass_through_loss: 113.4327 - val_loss: 272.2887 - val_distortion_loss: 0.0913 - val_rate_loss: 89.6909 - val_distortion_pass_through_loss: 0.0913 - val_rate_pass_through_loss: 89.6820
# Epoch 12/100
# 199/199 [==============================] - 2s 11ms/step - loss: 277.7289 - distortion_loss: 0.0837 - rate_loss: 110.2927 - distortion_pass_through_loss: 0.0837 - rate_pass_through_loss: 110.2899 - val_loss: 266.2332 - val_distortion_loss: 0.0900 - val_rate_loss: 86.2356 - val_distortion_pass_through_loss: 0.0900 - val_rate_pass_through_loss: 86.2298
# Epoch 13/100
# 199/199 [==============================] - 3s 13ms/step - loss: 274.0859 - distortion_loss: 0.0832 - rate_loss: 107.5977 - distortion_pass_through_loss: 0.0832 - rate_pass_through_loss: 107.5951 - val_loss: 262.2729 - val_distortion_loss: 0.0891 - val_rate_loss: 84.0335 - val_distortion_pass_through_loss: 0.0891 - val_rate_pass_through_loss: 84.0281
# Epoch 14/100
# 199/199 [==============================] - 2s 9ms/step - loss: 270.8060 - distortion_loss: 0.0827 - rate_loss: 105.4836 - distortion_pass_through_loss: 0.0827 - rate_pass_through_loss: 105.4809 - val_loss: 258.4030 - val_distortion_loss: 0.0885 - val_rate_loss: 81.4692 - val_distortion_pass_through_loss: 0.0885 - val_rate_pass_through_loss: 81.4649
# Epoch 15/100
# 199/199 [==============================] - 2s 9ms/step - loss: 268.0894 - distortion_loss: 0.0823 - rate_loss: 103.5545 - distortion_pass_through_loss: 0.0823 - rate_pass_through_loss: 103.5526 - val_loss: 255.9059 - val_distortion_loss: 0.0876 - val_rate_loss: 80.6157 - val_distortion_pass_through_loss: 0.0877 - val_rate_pass_through_loss: 80.6086
# Epoch 16/100
# 199/199 [==============================] - 2s 9ms/step - loss: 265.9682 - distortion_loss: 0.0821 - rate_loss: 101.8315 - distortion_pass_through_loss: 0.0821 - rate_pass_through_loss: 101.8297 - val_loss: 253.8621 - val_distortion_loss: 0.0870 - val_rate_loss: 79.8765 - val_distortion_pass_through_loss: 0.0870 - val_rate_pass_through_loss: 79.8731
# Epoch 17/100
# 199/199 [==============================] - 2s 9ms/step - loss: 263.8152 - distortion_loss: 0.0817 - rate_loss: 100.4422 - distortion_pass_through_loss: 0.0817 - rate_pass_through_loss: 100.4410 - val_loss: 252.7756 - val_distortion_loss: 0.0863 - val_rate_loss: 80.2472 - val_distortion_pass_through_loss: 0.0863 - val_rate_pass_through_loss: 80.2442
# Epoch 18/100
# 199/199 [==============================] - 3s 15ms/step - loss: 262.1440 - distortion_loss: 0.0815 - rate_loss: 99.0875 - distortion_pass_through_loss: 0.0815 - rate_pass_through_loss: 99.0856 - val_loss: 251.1175 - val_distortion_loss: 0.0860 - val_rate_loss: 79.0994 - val_distortion_pass_through_loss: 0.0860 - val_rate_pass_through_loss: 79.0965
# Epoch 19/100
# 199/199 [==============================] - 2s 10ms/step - loss: 260.2818 - distortion_loss: 0.0811 - rate_loss: 97.9934 - distortion_pass_through_loss: 0.0811 - rate_pass_through_loss: 97.9918 - val_loss: 249.8911 - val_distortion_loss: 0.0851 - val_rate_loss: 79.5947 - val_distortion_pass_through_loss: 0.0852 - val_rate_pass_through_loss: 79.5940
# Epoch 20/100
# 199/199 [==============================] - 2s 8ms/step - loss: 258.7417 - distortion_loss: 0.0809 - rate_loss: 96.8989 - distortion_pass_through_loss: 0.0809 - rate_pass_through_loss: 96.8976 - val_loss: 248.8160 - val_distortion_loss: 0.0847 - val_rate_loss: 79.4126 - val_distortion_pass_through_loss: 0.0847 - val_rate_pass_through_loss: 79.4084
# Epoch 21/100
# 199/199 [==============================] - 2s 9ms/step - loss: 257.4673 - distortion_loss: 0.0808 - rate_loss: 95.9546 - distortion_pass_through_loss: 0.0808 - rate_pass_through_loss: 95.9517 - val_loss: 248.8395 - val_distortion_loss: 0.0846 - val_rate_loss: 79.7226 - val_distortion_pass_through_loss: 0.0846 - val_rate_pass_through_loss: 79.7194
# Epoch 22/100
# 199/199 [==============================] - 2s 9ms/step - loss: 256.5740 - distortion_loss: 0.0808 - rate_loss: 95.0739 - distortion_pass_through_loss: 0.0807 - rate_pass_through_loss: 95.0725 - val_loss: 248.3808 - val_distortion_loss: 0.0843 - val_rate_loss: 79.7845 - val_distortion_pass_through_loss: 0.0843 - val_rate_pass_through_loss: 79.7820
# Epoch 23/100
# 199/199 [==============================] - 2s 9ms/step - loss: 255.2692 - distortion_loss: 0.0805 - rate_loss: 94.2961 - distortion_pass_through_loss: 0.0805 - rate_pass_through_loss: 94.2947 - val_loss: 247.9300 - val_distortion_loss: 0.0837 - val_rate_loss: 80.6058 - val_distortion_pass_through_loss: 0.0837 - val_rate_pass_through_loss: 80.6038
# Epoch 24/100
# 199/199 [==============================] - 3s 14ms/step - loss: 254.3289 - distortion_loss: 0.0804 - rate_loss: 93.5663 - distortion_pass_through_loss: 0.0804 - rate_pass_through_loss: 93.5654 - val_loss: 248.9868 - val_distortion_loss: 0.0838 - val_rate_loss: 81.3439 - val_distortion_pass_through_loss: 0.0838 - val_rate_pass_through_loss: 81.3453
# Epoch 25/100
# 199/199 [==============================] - 2s 9ms/step - loss: 253.2179 - distortion_loss: 0.0802 - rate_loss: 92.8759 - distortion_pass_through_loss: 0.0802 - rate_pass_through_loss: 92.8755 - val_loss: 247.1574 - val_distortion_loss: 0.0829 - val_rate_loss: 81.4095 - val_distortion_pass_through_loss: 0.0829 - val_rate_pass_through_loss: 81.4100
# Epoch 26/100
# 199/199 [==============================] - 2s 9ms/step - loss: 252.4724 - distortion_loss: 0.0801 - rate_loss: 92.3653 - distortion_pass_through_loss: 0.0800 - rate_pass_through_loss: 92.3621 - val_loss: 247.0968 - val_distortion_loss: 0.0833 - val_rate_loss: 80.4970 - val_distortion_pass_through_loss: 0.0833 - val_rate_pass_through_loss: 80.4974
# Epoch 27/100
# 199/199 [==============================] - 2s 9ms/step - loss: 251.5343 - distortion_loss: 0.0799 - rate_loss: 91.7613 - distortion_pass_through_loss: 0.0799 - rate_pass_through_loss: 91.7591 - val_loss: 246.0829 - val_distortion_loss: 0.0826 - val_rate_loss: 80.8839 - val_distortion_pass_through_loss: 0.0826 - val_rate_pass_through_loss: 80.8839
# Epoch 28/100
# 199/199 [==============================] - 2s 9ms/step - loss: 251.1271 - distortion_loss: 0.0799 - rate_loss: 91.2815 - distortion_pass_through_loss: 0.0799 - rate_pass_through_loss: 91.2807 - val_loss: 245.8436 - val_distortion_loss: 0.0823 - val_rate_loss: 81.3325 - val_distortion_pass_through_loss: 0.0823 - val_rate_pass_through_loss: 81.3336
# Epoch 29/100
# 199/199 [==============================] - 2s 9ms/step - loss: 249.8793 - distortion_loss: 0.0795 - rate_loss: 90.8767 - distortion_pass_through_loss: 0.0795 - rate_pass_through_loss: 90.8745 - val_loss: 246.1100 - val_distortion_loss: 0.0823 - val_rate_loss: 81.5882 - val_distortion_pass_through_loss: 0.0823 - val_rate_pass_through_loss: 81.5912
# Epoch 30/100
# 199/199 [==============================] - 3s 14ms/step - loss: 249.2085 - distortion_loss: 0.0794 - rate_loss: 90.4896 - distortion_pass_through_loss: 0.0794 - rate_pass_through_loss: 90.4879 - val_loss: 246.7223 - val_distortion_loss: 0.0829 - val_rate_loss: 80.9892 - val_distortion_pass_through_loss: 0.0829 - val_rate_pass_through_loss: 80.9923
# Epoch 31/100
# 199/199 [==============================] - 4s 19ms/step - loss: 248.9547 - distortion_loss: 0.0794 - rate_loss: 90.1102 - distortion_pass_through_loss: 0.0794 - rate_pass_through_loss: 90.1092 - val_loss: 245.0544 - val_distortion_loss: 0.0817 - val_rate_loss: 81.6508 - val_distortion_pass_through_loss: 0.0817 - val_rate_pass_through_loss: 81.6536
# Epoch 32/100
# 199/199 [==============================] - 2s 9ms/step - loss: 248.3245 - distortion_loss: 0.0793 - rate_loss: 89.7590 - distortion_pass_through_loss: 0.0793 - rate_pass_through_loss: 89.7576 - val_loss: 245.5292 - val_distortion_loss: 0.0817 - val_rate_loss: 82.0463 - val_distortion_pass_through_loss: 0.0818 - val_rate_pass_through_loss: 82.0481
# Epoch 33/100
# 199/199 [==============================] - 2s 9ms/step - loss: 247.6005 - distortion_loss: 0.0790 - rate_loss: 89.5191 - distortion_pass_through_loss: 0.0790 - rate_pass_through_loss: 89.5182 - val_loss: 245.1536 - val_distortion_loss: 0.0817 - val_rate_loss: 81.8382 - val_distortion_pass_through_loss: 0.0817 - val_rate_pass_through_loss: 81.8402
# Epoch 34/100
# 199/199 [==============================] - 2s 10ms/step - loss: 247.0906 - distortion_loss: 0.0790 - rate_loss: 89.1225 - distortion_pass_through_loss: 0.0790 - rate_pass_through_loss: 89.1210 - val_loss: 244.8072 - val_distortion_loss: 0.0812 - val_rate_loss: 82.3280 - val_distortion_pass_through_loss: 0.0813 - val_rate_pass_through_loss: 82.3331
# Epoch 35/100
# 199/199 [==============================] - 3s 13ms/step - loss: 246.6559 - distortion_loss: 0.0789 - rate_loss: 88.9375 - distortion_pass_through_loss: 0.0789 - rate_pass_through_loss: 88.9361 - val_loss: 245.3562 - val_distortion_loss: 0.0821 - val_rate_loss: 81.1131 - val_distortion_pass_through_loss: 0.0821 - val_rate_pass_through_loss: 81.1166
# Epoch 36/100
# 199/199 [==============================] - 2s 10ms/step - loss: 246.4282 - distortion_loss: 0.0789 - rate_loss: 88.7066 - distortion_pass_through_loss: 0.0789 - rate_pass_through_loss: 88.7047 - val_loss: 244.7125 - val_distortion_loss: 0.0815 - val_rate_loss: 81.7932 - val_distortion_pass_through_loss: 0.0815 - val_rate_pass_through_loss: 81.7952
# Epoch 37/100
# 199/199 [==============================] - 2s 8ms/step - loss: 245.8833 - distortion_loss: 0.0787 - rate_loss: 88.5239 - distortion_pass_through_loss: 0.0787 - rate_pass_through_loss: 88.5218 - val_loss: 245.1387 - val_distortion_loss: 0.0814 - val_rate_loss: 82.4064 - val_distortion_pass_through_loss: 0.0814 - val_rate_pass_through_loss: 82.4096
# Epoch 38/100
# 199/199 [==============================] - 2s 9ms/step - loss: 245.5792 - distortion_loss: 0.0786 - rate_loss: 88.3412 - distortion_pass_through_loss: 0.0786 - rate_pass_through_loss: 88.3396 - val_loss: 244.7699 - val_distortion_loss: 0.0815 - val_rate_loss: 81.8466 - val_distortion_pass_through_loss: 0.0815 - val_rate_pass_through_loss: 81.8495
# Epoch 39/100
# 199/199 [==============================] - 2s 9ms/step - loss: 245.2758 - distortion_loss: 0.0786 - rate_loss: 88.1423 - distortion_pass_through_loss: 0.0786 - rate_pass_through_loss: 88.1413 - val_loss: 244.2448 - val_distortion_loss: 0.0811 - val_rate_loss: 82.0003 - val_distortion_pass_through_loss: 0.0811 - val_rate_pass_through_loss: 82.0031
# Epoch 40/100
# 199/199 [==============================] - 2s 8ms/step - loss: 245.1062 - distortion_loss: 0.0786 - rate_loss: 87.9280 - distortion_pass_through_loss: 0.0786 - rate_pass_through_loss: 87.9270 - val_loss: 244.3717 - val_distortion_loss: 0.0813 - val_rate_loss: 81.6729 - val_distortion_pass_through_loss: 0.0814 - val_rate_pass_through_loss: 81.6769
# Epoch 41/100
# 199/199 [==============================] - 2s 12ms/step - loss: 244.5307 - distortion_loss: 0.0784 - rate_loss: 87.8001 - distortion_pass_through_loss: 0.0784 - rate_pass_through_loss: 87.7985 - val_loss: 244.7001 - val_distortion_loss: 0.0816 - val_rate_loss: 81.4607 - val_distortion_pass_through_loss: 0.0816 - val_rate_pass_through_loss: 81.4645
# Epoch 42/100
# 199/199 [==============================] - 3s 13ms/step - loss: 244.2999 - distortion_loss: 0.0783 - rate_loss: 87.6551 - distortion_pass_through_loss: 0.0783 - rate_pass_through_loss: 87.6537 - val_loss: 244.5180 - val_distortion_loss: 0.0811 - val_rate_loss: 82.3413 - val_distortion_pass_through_loss: 0.0811 - val_rate_pass_through_loss: 82.3432
# Epoch 43/100
# 199/199 [==============================] - 2s 9ms/step - loss: 244.0972 - distortion_loss: 0.0783 - rate_loss: 87.5444 - distortion_pass_through_loss: 0.0783 - rate_pass_through_loss: 87.5433 - val_loss: 244.2498 - val_distortion_loss: 0.0810 - val_rate_loss: 82.2137 - val_distortion_pass_through_loss: 0.0810 - val_rate_pass_through_loss: 82.2163
# Epoch 44/100
# 199/199 [==============================] - 2s 9ms/step - loss: 244.0935 - distortion_loss: 0.0783 - rate_loss: 87.4005 - distortion_pass_through_loss: 0.0783 - rate_pass_through_loss: 87.3995 - val_loss: 244.7201 - val_distortion_loss: 0.0816 - val_rate_loss: 81.5573 - val_distortion_pass_through_loss: 0.0816 - val_rate_pass_through_loss: 81.5600
# Epoch 45/100
# 199/199 [==============================] - 2s 9ms/step - loss: 243.5729 - distortion_loss: 0.0781 - rate_loss: 87.3728 - distortion_pass_through_loss: 0.0781 - rate_pass_through_loss: 87.3717 - val_loss: 244.1506 - val_distortion_loss: 0.0811 - val_rate_loss: 81.8742 - val_distortion_pass_through_loss: 0.0812 - val_rate_pass_through_loss: 81.8771
# Epoch 46/100
# 199/199 [==============================] - 2s 8ms/step - loss: 243.3643 - distortion_loss: 0.0780 - rate_loss: 87.3073 - distortion_pass_through_loss: 0.0780 - rate_pass_through_loss: 87.3072 - val_loss: 244.5172 - val_distortion_loss: 0.0811 - val_rate_loss: 82.2349 - val_distortion_pass_through_loss: 0.0812 - val_rate_pass_through_loss: 82.2373
# Epoch 47/100
# 199/199 [==============================] - 3s 13ms/step - loss: 243.1620 - distortion_loss: 0.0780 - rate_loss: 87.2448 - distortion_pass_through_loss: 0.0780 - rate_pass_through_loss: 87.2433 - val_loss: 244.1872 - val_distortion_loss: 0.0812 - val_rate_loss: 81.7895 - val_distortion_pass_through_loss: 0.0812 - val_rate_pass_through_loss: 81.7921
# Epoch 48/100
# 199/199 [==============================] - 2s 11ms/step - loss: 243.0330 - distortion_loss: 0.0779 - rate_loss: 87.1813 - distortion_pass_through_loss: 0.0779 - rate_pass_through_loss: 87.1798 - val_loss: 244.3639 - val_distortion_loss: 0.0812 - val_rate_loss: 82.0529 - val_distortion_pass_through_loss: 0.0812 - val_rate_pass_through_loss: 82.0543
# Epoch 49/100
# 199/199 [==============================] - 2s 8ms/step - loss: 242.6576 - distortion_loss: 0.0778 - rate_loss: 87.0099 - distortion_pass_through_loss: 0.0778 - rate_pass_through_loss: 87.0096 - val_loss: 243.9550 - val_distortion_loss: 0.0809 - val_rate_loss: 82.1050 - val_distortion_pass_through_loss: 0.0809 - val_rate_pass_through_loss: 82.1088
# Epoch 50/100
# 199/199 [==============================] - 2s 9ms/step - loss: 242.4350 - distortion_loss: 0.0777 - rate_loss: 86.9941 - distortion_pass_through_loss: 0.0777 - rate_pass_through_loss: 86.9933 - val_loss: 243.6974 - val_distortion_loss: 0.0807 - val_rate_loss: 82.2796 - val_distortion_pass_through_loss: 0.0807 - val_rate_pass_through_loss: 82.2823
# Epoch 51/100
# 199/199 [==============================] - 2s 8ms/step - loss: 242.1658 - distortion_loss: 0.0776 - rate_loss: 86.9887 - distortion_pass_through_loss: 0.0776 - rate_pass_through_loss: 86.9882 - val_loss: 243.8651 - val_distortion_loss: 0.0808 - val_rate_loss: 82.2092 - val_distortion_pass_through_loss: 0.0808 - val_rate_pass_through_loss: 82.2098
# Epoch 52/100
# 199/199 [==============================] - 2s 9ms/step - loss: 242.2449 - distortion_loss: 0.0776 - rate_loss: 86.9495 - distortion_pass_through_loss: 0.0776 - rate_pass_through_loss: 86.9480 - val_loss: 243.6292 - val_distortion_loss: 0.0805 - val_rate_loss: 82.5922 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.5942
# Epoch 53/100
# 199/199 [==============================] - 2s 10ms/step - loss: 241.7690 - distortion_loss: 0.0774 - rate_loss: 86.9522 - distortion_pass_through_loss: 0.0774 - rate_pass_through_loss: 86.9522 - val_loss: 243.7194 - val_distortion_loss: 0.0806 - val_rate_loss: 82.5534 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.5538
# Epoch 54/100
# 199/199 [==============================] - 3s 14ms/step - loss: 241.5632 - distortion_loss: 0.0773 - rate_loss: 86.9099 - distortion_pass_through_loss: 0.0773 - rate_pass_through_loss: 86.9095 - val_loss: 243.6561 - val_distortion_loss: 0.0805 - val_rate_loss: 82.7300 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.7334
# Epoch 55/100
# 199/199 [==============================] - 2s 10ms/step - loss: 241.5634 - distortion_loss: 0.0774 - rate_loss: 86.8589 - distortion_pass_through_loss: 0.0773 - rate_pass_through_loss: 86.8578 - val_loss: 244.7792 - val_distortion_loss: 0.0810 - val_rate_loss: 82.7333 - val_distortion_pass_through_loss: 0.0810 - val_rate_pass_through_loss: 82.7332
# Epoch 56/100
# 199/199 [==============================] - 2s 9ms/step - loss: 241.3537 - distortion_loss: 0.0773 - rate_loss: 86.8110 - distortion_pass_through_loss: 0.0773 - rate_pass_through_loss: 86.8106 - val_loss: 244.0497 - val_distortion_loss: 0.0809 - val_rate_loss: 82.3016 - val_distortion_pass_through_loss: 0.0809 - val_rate_pass_through_loss: 82.3036
# Epoch 57/100
# 199/199 [==============================] - 2s 9ms/step - loss: 241.3179 - distortion_loss: 0.0772 - rate_loss: 86.8383 - distortion_pass_through_loss: 0.0772 - rate_pass_through_loss: 86.8366 - val_loss: 243.5455 - val_distortion_loss: 0.0807 - val_rate_loss: 82.1065 - val_distortion_pass_through_loss: 0.0807 - val_rate_pass_through_loss: 82.1080
# Epoch 58/100
# 199/199 [==============================] - 2s 8ms/step - loss: 240.8830 - distortion_loss: 0.0770 - rate_loss: 86.8256 - distortion_pass_through_loss: 0.0770 - rate_pass_through_loss: 86.8247 - val_loss: 244.8774 - val_distortion_loss: 0.0818 - val_rate_loss: 81.3365 - val_distortion_pass_through_loss: 0.0818 - val_rate_pass_through_loss: 81.3394
# Epoch 59/100
# 199/199 [==============================] - 2s 9ms/step - loss: 241.2420 - distortion_loss: 0.0772 - rate_loss: 86.8372 - distortion_pass_through_loss: 0.0772 - rate_pass_through_loss: 86.8360 - val_loss: 243.4702 - val_distortion_loss: 0.0806 - val_rate_loss: 82.2351 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.2377
# Epoch 60/100
# 199/199 [==============================] - 2s 12ms/step - loss: 240.7041 - distortion_loss: 0.0769 - rate_loss: 86.8291 - distortion_pass_through_loss: 0.0769 - rate_pass_through_loss: 86.8283 - val_loss: 243.9669 - val_distortion_loss: 0.0807 - val_rate_loss: 82.5807 - val_distortion_pass_through_loss: 0.0807 - val_rate_pass_through_loss: 82.5805
# Epoch 61/100
# 199/199 [==============================] - 3s 13ms/step - loss: 240.9176 - distortion_loss: 0.0770 - rate_loss: 86.8766 - distortion_pass_through_loss: 0.0770 - rate_pass_through_loss: 86.8748 - val_loss: 243.9160 - val_distortion_loss: 0.0811 - val_rate_loss: 81.6231 - val_distortion_pass_through_loss: 0.0812 - val_rate_pass_through_loss: 81.6260
# Epoch 62/100
# 199/199 [==============================] - 2s 9ms/step - loss: 240.5370 - distortion_loss: 0.0768 - rate_loss: 86.8661 - distortion_pass_through_loss: 0.0768 - rate_pass_through_loss: 86.8652 - val_loss: 243.2508 - val_distortion_loss: 0.0804 - val_rate_loss: 82.4743 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 82.4755
# Epoch 63/100
# 199/199 [==============================] - 2s 8ms/step - loss: 240.7734 - distortion_loss: 0.0770 - rate_loss: 86.8243 - distortion_pass_through_loss: 0.0770 - rate_pass_through_loss: 86.8220 - val_loss: 245.0336 - val_distortion_loss: 0.0815 - val_rate_loss: 81.9799 - val_distortion_pass_through_loss: 0.0815 - val_rate_pass_through_loss: 81.9814
# Epoch 64/100
# 199/199 [==============================] - 2s 9ms/step - loss: 240.1847 - distortion_loss: 0.0767 - rate_loss: 86.8419 - distortion_pass_through_loss: 0.0767 - rate_pass_through_loss: 86.8406 - val_loss: 243.8842 - val_distortion_loss: 0.0810 - val_rate_loss: 81.8649 - val_distortion_pass_through_loss: 0.0810 - val_rate_pass_through_loss: 81.8702
# Epoch 65/100
# 199/199 [==============================] - 2s 9ms/step - loss: 240.0697 - distortion_loss: 0.0766 - rate_loss: 86.8681 - distortion_pass_through_loss: 0.0766 - rate_pass_through_loss: 86.8675 - val_loss: 243.3154 - val_distortion_loss: 0.0805 - val_rate_loss: 82.3878 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.3904
# Epoch 66/100
# 199/199 [==============================] - 2s 9ms/step - loss: 240.0988 - distortion_loss: 0.0766 - rate_loss: 86.8837 - distortion_pass_through_loss: 0.0766 - rate_pass_through_loss: 86.8829 - val_loss: 243.2974 - val_distortion_loss: 0.0803 - val_rate_loss: 82.7440 - val_distortion_pass_through_loss: 0.0803 - val_rate_pass_through_loss: 82.7466
# Epoch 67/100
# 199/199 [==============================] - 3s 13ms/step - loss: 239.6704 - distortion_loss: 0.0764 - rate_loss: 86.9100 - distortion_pass_through_loss: 0.0764 - rate_pass_through_loss: 86.9087 - val_loss: 243.5436 - val_distortion_loss: 0.0802 - val_rate_loss: 83.0631 - val_distortion_pass_through_loss: 0.0803 - val_rate_pass_through_loss: 83.0672
# Epoch 68/100
# 199/199 [==============================] - 3s 13ms/step - loss: 239.6860 - distortion_loss: 0.0764 - rate_loss: 86.9327 - distortion_pass_through_loss: 0.0764 - rate_pass_through_loss: 86.9320 - val_loss: 244.1896 - val_distortion_loss: 0.0809 - val_rate_loss: 82.3846 - val_distortion_pass_through_loss: 0.0809 - val_rate_pass_through_loss: 82.3875
# Epoch 69/100
# 199/199 [==============================] - 2s 9ms/step - loss: 239.5324 - distortion_loss: 0.0763 - rate_loss: 86.9233 - distortion_pass_through_loss: 0.0763 - rate_pass_through_loss: 86.9219 - val_loss: 244.4065 - val_distortion_loss: 0.0808 - val_rate_loss: 82.7929 - val_distortion_pass_through_loss: 0.0808 - val_rate_pass_through_loss: 82.7979
# Epoch 70/100
# 199/199 [==============================] - 2s 9ms/step - loss: 239.5023 - distortion_loss: 0.0763 - rate_loss: 86.8767 - distortion_pass_through_loss: 0.0763 - rate_pass_through_loss: 86.8746 - val_loss: 244.0407 - val_distortion_loss: 0.0807 - val_rate_loss: 82.5849 - val_distortion_pass_through_loss: 0.0807 - val_rate_pass_through_loss: 82.5877
# Epoch 71/100
# 199/199 [==============================] - 2s 9ms/step - loss: 239.3347 - distortion_loss: 0.0762 - rate_loss: 86.9221 - distortion_pass_through_loss: 0.0762 - rate_pass_through_loss: 86.9196 - val_loss: 243.4497 - val_distortion_loss: 0.0804 - val_rate_loss: 82.6001 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 82.6039
# Epoch 72/100
# 199/199 [==============================] - 2s 9ms/step - loss: 239.4627 - distortion_loss: 0.0763 - rate_loss: 86.9356 - distortion_pass_through_loss: 0.0763 - rate_pass_through_loss: 86.9339 - val_loss: 244.0540 - val_distortion_loss: 0.0809 - val_rate_loss: 82.2427 - val_distortion_pass_through_loss: 0.0809 - val_rate_pass_through_loss: 82.2479
# Epoch 73/100
# 199/199 [==============================] - 2s 12ms/step - loss: 239.0542 - distortion_loss: 0.0760 - rate_loss: 86.9854 - distortion_pass_through_loss: 0.0760 - rate_pass_through_loss: 86.9852 - val_loss: 243.4194 - val_distortion_loss: 0.0805 - val_rate_loss: 82.5152 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.5193
# Epoch 74/100
# 199/199 [==============================] - 3s 14ms/step - loss: 238.8881 - distortion_loss: 0.0759 - rate_loss: 87.0237 - distortion_pass_through_loss: 0.0759 - rate_pass_through_loss: 87.0220 - val_loss: 243.4720 - val_distortion_loss: 0.0803 - val_rate_loss: 82.9708 - val_distortion_pass_through_loss: 0.0803 - val_rate_pass_through_loss: 82.9747
# Epoch 75/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.8885 - distortion_loss: 0.0760 - rate_loss: 86.9678 - distortion_pass_through_loss: 0.0760 - rate_pass_through_loss: 86.9668 - val_loss: 243.8849 - val_distortion_loss: 0.0804 - val_rate_loss: 83.1322 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 83.1357
# Epoch 76/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.6809 - distortion_loss: 0.0758 - rate_loss: 87.0478 - distortion_pass_through_loss: 0.0758 - rate_pass_through_loss: 87.0465 - val_loss: 243.6325 - val_distortion_loss: 0.0806 - val_rate_loss: 82.5037 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.5084
# Epoch 77/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.8226 - distortion_loss: 0.0759 - rate_loss: 86.9714 - distortion_pass_through_loss: 0.0759 - rate_pass_through_loss: 86.9712 - val_loss: 244.1639 - val_distortion_loss: 0.0810 - val_rate_loss: 82.1352 - val_distortion_pass_through_loss: 0.0810 - val_rate_pass_through_loss: 82.1382
# Epoch 78/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.8893 - distortion_loss: 0.0759 - rate_loss: 87.0004 - distortion_pass_through_loss: 0.0759 - rate_pass_through_loss: 86.9993 - val_loss: 243.8674 - val_distortion_loss: 0.0805 - val_rate_loss: 82.7736 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.7786
# Epoch 79/100
# 199/199 [==============================] - 2s 11ms/step - loss: 238.1714 - distortion_loss: 0.0756 - rate_loss: 87.0248 - distortion_pass_through_loss: 0.0756 - rate_pass_through_loss: 87.0235 - val_loss: 243.5469 - val_distortion_loss: 0.0804 - val_rate_loss: 82.7347 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 82.7387
# Epoch 80/100
# 199/199 [==============================] - 3s 14ms/step - loss: 238.2529 - distortion_loss: 0.0756 - rate_loss: 87.0904 - distortion_pass_through_loss: 0.0756 - rate_pass_through_loss: 87.0901 - val_loss: 243.6271 - val_distortion_loss: 0.0803 - val_rate_loss: 83.1026 - val_distortion_pass_through_loss: 0.0803 - val_rate_pass_through_loss: 83.1074
# Epoch 81/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.2109 - distortion_loss: 0.0756 - rate_loss: 87.0004 - distortion_pass_through_loss: 0.0756 - rate_pass_through_loss: 86.9997 - val_loss: 243.8443 - val_distortion_loss: 0.0803 - val_rate_loss: 83.2993 - val_distortion_pass_through_loss: 0.0803 - val_rate_pass_through_loss: 83.3040
# Epoch 82/100
# 199/199 [==============================] - 3s 13ms/step - loss: 238.1804 - distortion_loss: 0.0755 - rate_loss: 87.0824 - distortion_pass_through_loss: 0.0755 - rate_pass_through_loss: 87.0806 - val_loss: 244.0844 - val_distortion_loss: 0.0803 - val_rate_loss: 83.3903 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 83.3943
# Epoch 83/100
# 199/199 [==============================] - 2s 9ms/step - loss: 238.1363 - distortion_loss: 0.0755 - rate_loss: 87.1150 - distortion_pass_through_loss: 0.0755 - rate_pass_through_loss: 87.1144 - val_loss: 245.1620 - val_distortion_loss: 0.0818 - val_rate_loss: 81.5040 - val_distortion_pass_through_loss: 0.0818 - val_rate_pass_through_loss: 81.5105
# Epoch 84/100
# 199/199 [==============================] - 3s 14ms/step - loss: 237.7625 - distortion_loss: 0.0753 - rate_loss: 87.0757 - distortion_pass_through_loss: 0.0753 - rate_pass_through_loss: 87.0750 - val_loss: 244.2663 - val_distortion_loss: 0.0805 - val_rate_loss: 83.2316 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 83.2353
# Epoch 85/100
# 199/199 [==============================] - 2s 10ms/step - loss: 237.7964 - distortion_loss: 0.0753 - rate_loss: 87.1076 - distortion_pass_through_loss: 0.0753 - rate_pass_through_loss: 87.1068 - val_loss: 243.9225 - val_distortion_loss: 0.0805 - val_rate_loss: 82.9764 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.9796
# Epoch 86/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.8532 - distortion_loss: 0.0754 - rate_loss: 87.1286 - distortion_pass_through_loss: 0.0754 - rate_pass_through_loss: 87.1273 - val_loss: 243.9694 - val_distortion_loss: 0.0804 - val_rate_loss: 83.2228 - val_distortion_pass_through_loss: 0.0804 - val_rate_pass_through_loss: 83.2260
# Epoch 87/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.5984 - distortion_loss: 0.0752 - rate_loss: 87.1620 - distortion_pass_through_loss: 0.0752 - rate_pass_through_loss: 87.1617 - val_loss: 243.7739 - val_distortion_loss: 0.0804 - val_rate_loss: 82.9114 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.9175
# Epoch 88/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.5162 - distortion_loss: 0.0751 - rate_loss: 87.2272 - distortion_pass_through_loss: 0.0751 - rate_pass_through_loss: 87.2259 - val_loss: 243.6820 - val_distortion_loss: 0.0805 - val_rate_loss: 82.5925 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.5975
# Epoch 89/100
# 199/199 [==============================] - 2s 12ms/step - loss: 237.4599 - distortion_loss: 0.0751 - rate_loss: 87.1824 - distortion_pass_through_loss: 0.0751 - rate_pass_through_loss: 87.1809 - val_loss: 243.8913 - val_distortion_loss: 0.0805 - val_rate_loss: 82.9327 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.9363
# Epoch 90/100
# 199/199 [==============================] - 3s 13ms/step - loss: 237.1934 - distortion_loss: 0.0750 - rate_loss: 87.1606 - distortion_pass_through_loss: 0.0750 - rate_pass_through_loss: 87.1595 - val_loss: 243.9830 - val_distortion_loss: 0.0805 - val_rate_loss: 83.0718 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 83.0756
# Epoch 91/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.3204 - distortion_loss: 0.0750 - rate_loss: 87.2828 - distortion_pass_through_loss: 0.0750 - rate_pass_through_loss: 87.2813 - val_loss: 244.0494 - val_distortion_loss: 0.0806 - val_rate_loss: 82.8362 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.8416
# Epoch 92/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.3422 - distortion_loss: 0.0751 - rate_loss: 87.2173 - distortion_pass_through_loss: 0.0751 - rate_pass_through_loss: 87.2171 - val_loss: 244.1063 - val_distortion_loss: 0.0802 - val_rate_loss: 83.6909 - val_distortion_pass_through_loss: 0.0802 - val_rate_pass_through_loss: 83.6944
# Epoch 93/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.2763 - distortion_loss: 0.0750 - rate_loss: 87.2371 - distortion_pass_through_loss: 0.0750 - rate_pass_through_loss: 87.2367 - val_loss: 244.2749 - val_distortion_loss: 0.0805 - val_rate_loss: 83.3334 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 83.3368
# Epoch 94/100
# 199/199 [==============================] - 2s 9ms/step - loss: 237.2305 - distortion_loss: 0.0750 - rate_loss: 87.2886 - distortion_pass_through_loss: 0.0750 - rate_pass_through_loss: 87.2869 - val_loss: 244.6665 - val_distortion_loss: 0.0808 - val_rate_loss: 83.1511 - val_distortion_pass_through_loss: 0.0808 - val_rate_pass_through_loss: 83.1552
# Epoch 95/100
# 199/199 [==============================] - 2s 12ms/step - loss: 237.0658 - distortion_loss: 0.0749 - rate_loss: 87.2489 - distortion_pass_through_loss: 0.0749 - rate_pass_through_loss: 87.2471 - val_loss: 244.1971 - val_distortion_loss: 0.0805 - val_rate_loss: 83.1810 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 83.1835
# Epoch 96/100
# 199/199 [==============================] - 3s 13ms/step - loss: 237.1688 - distortion_loss: 0.0749 - rate_loss: 87.2988 - distortion_pass_through_loss: 0.0749 - rate_pass_through_loss: 87.2969 - val_loss: 244.3611 - val_distortion_loss: 0.0810 - val_rate_loss: 82.2769 - val_distortion_pass_through_loss: 0.0811 - val_rate_pass_through_loss: 82.2805
# Epoch 97/100
# 199/199 [==============================] - 2s 10ms/step - loss: 236.8452 - distortion_loss: 0.0748 - rate_loss: 87.2839 - distortion_pass_through_loss: 0.0748 - rate_pass_through_loss: 87.2835 - val_loss: 244.8322 - val_distortion_loss: 0.0813 - val_rate_loss: 82.1867 - val_distortion_pass_through_loss: 0.0813 - val_rate_pass_through_loss: 82.1918
# Epoch 98/100
# 199/199 [==============================] - 2s 9ms/step - loss: 236.5797 - distortion_loss: 0.0746 - rate_loss: 87.3427 - distortion_pass_through_loss: 0.0746 - rate_pass_through_loss: 87.3413 - val_loss: 245.1807 - val_distortion_loss: 0.0811 - val_rate_loss: 83.0695 - val_distortion_pass_through_loss: 0.0811 - val_rate_pass_through_loss: 83.0748
# Epoch 99/100
# 199/199 [==============================] - 2s 9ms/step - loss: 236.4299 - distortion_loss: 0.0745 - rate_loss: 87.4007 - distortion_pass_through_loss: 0.0745 - rate_pass_through_loss: 87.3991 - val_loss: 243.7036 - val_distortion_loss: 0.0806 - val_rate_loss: 82.5999 - val_distortion_pass_through_loss: 0.0806 - val_rate_pass_through_loss: 82.6041
# Epoch 100/100
# 199/199 [==============================] - 2s 11ms/step - loss: 236.1000 - distortion_loss: 0.0744 - rate_loss: 87.3694 - distortion_pass_through_loss: 0.0744 - rate_pass_through_loss: 87.3685 - val_loss: 243.8805 - val_distortion_loss: 0.0805 - val_rate_loss: 82.9364 - val_distortion_pass_through_loss: 0.0805 - val_rate_pass_through_loss: 82.9420

# %%
# show the analysis_transform model
trainer.analysis_transform.summary()

# show the model
trainer.synthesis_transform.summary()
# Out:
# Model: "analysis_transform"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 16, 16, 20)        520
#
#  conv_2 (Conv2D)             (None, 8, 8, 50)          25050
#
#  flatten (Flatten)           (None, 3200)              0
#
#  fc_1 (Dense)                (None, 500)               1600500
#
#  fc_2 (Dense)                (None, 100)               50100
#
# =================================================================
# Total params: 1,676,170
# Trainable params: 1,676,170
# Non-trainable params: 0
# _________________________________________________________________
# Model: "synthesis_transform"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc_1 (Dense)                (None, 500)               50500
#
#  fc_2 (Dense)                (None, 3200)              1603200
#
#  reshape (Reshape)           (None, 8, 8, 50)          0
#
#  conv_1 (Conv2DTranspose)    (None, 16, 16, 20)        25020
#
#  conv_2 (Conv2DTranspose)    (None, 32, 32, 1)         501
#
# =================================================================
# Total params: 1,679,221
# Trainable params: 1,679,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(trainer.analysis_transform, to_file='model_analysis_transform.png', show_shapes=True, show_dtype=True)

# %%
tf.keras.utils.plot_model(trainer.synthesis_transform, to_file='model_synthesis_transform.png', show_shapes=True, show_dtype=True)

# %%
# Save the model if we want
trainer.save_weights("./drive/MyDrive/Training Dataset/das_compression_model_%d"%(patch_size))

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'distortion_loss', 'rate_loss', 'distortion_pass_through_loss', 'rate_pass_through_loss', 'val_loss', 'val_distortion_loss', 'val_rate_loss', 'val_distortion_pass_through_loss', 'val_rate_pass_through_loss'])

# %%
# loss_list = ['loss', 'val_loss', 'rate_loss', 'distortion_loss']

loss_list = ['loss', 'val_loss']

# Plot the rate_loss curve.
plt.figure(figsize=(10,6))
for i, l in enumerate(loss_list):
  plt.subplot(2, 2, i + 1)
  plt.plot(history.history[l])
  plt.xlabel('#Epoch')
  plt.ylabel('Loss')
  plt.title(l)

plt.tight_layout()
plt.savefig('Loss.png', dpi=300, pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Compress and Decompress on Validation dataset
#
# For compression and decompression at test time, we split the trained model in two parts:
#
# - The encoder side consists of the analysis transform and the entropy model.
# - The decoder side consists of the synthesis transform and the same entropy model.
#
# At test time, the latents will not have additive noise, but they will be quantized and then losslessly compressed, so we give them new names. We call them and the image reconstruction $\hat x$ and $\hat y$, respectively (following [End-to-end Optimized Image Compression](https://arxiv.org/abs/1611.01704)).

# %%
class DASCompressor(tf.keras.Model):
  """Compresses DAS data to strings."""

  def __init__(self, analysis_transform, entropy_model):
    super().__init__()
    self.analysis_transform = analysis_transform
    self.entropy_model = entropy_model

  def call(self, x):
    # Ensure inputs are floats in the range (0, 1).
    x = tf.cast(x, self.compute_dtype) / 255.
    y = self.analysis_transform(x)
    # Also return the exact information content of each digit.
    _, bits = self.entropy_model(y, training=False)
    return self.entropy_model.compress(y), bits


class DASDecompressor(tf.keras.Model):
  """Decompresses DAS data from strings."""

  def __init__(self, entropy_model, synthesis_transform):
    super().__init__()
    self.entropy_model = entropy_model
    self.synthesis_transform = synthesis_transform

  def call(self, string):
    y_hat = self.entropy_model.decompress(string, ())
    x_hat = self.synthesis_transform(y_hat)
    # Scale and cast back to 8-bit integer.
    return tf.saturate_cast(tf.round(x_hat * 255.), tf.float32)

# %% [markdown]
# When instantiated with `compression=True`, the entropy model converts the learned prior into tables for a range coding algorithm. When calling `compress()`, this algorithm is invoked to convert the latent space vector into bit sequences. The length of each binary string approximates the information content of the latent (the negative log likelihood of the latent under the prior).
#
# The entropy model for compression and decompression must be the same instance, because the range coding tables need to be exactly identical on both sides. Otherwise, decoding errors can occur.

# %%
def make_das_codec(trainer, **kwargs):
  # The entropy model must be created with `compression=True` and the same
  # instance must be shared between compressor and decompressor.

  entropy_model = tfc.ContinuousBatchedEntropyModel(trainer.prior, coding_rank=1, compression=True, **kwargs)
  compressor = DASCompressor(trainer.analysis_transform, entropy_model)
  decompressor = DASDecompressor(entropy_model, trainer.synthesis_transform)
  
  return compressor, decompressor

# %%
# Setup the trained model 
compressor, decompressor = make_das_codec(trainer)

# Grab 16 images from the validation dataset. You can select a different subset by changing the argument to `skip`.
(originals, _), = validation_dataset.batch(128).skip(2).take(1)

# Compress them to strings, and keep track of each of their information content in bits.
strings, entropies = compressor(originals)

print(f"String representation of first digit in hexadecimal: 0x{strings[1].numpy().hex()}")
print(f"Number of bits actually needed to represent it: {entropies[1]:0.2f}")

# Decompress the images back from the strings.
reconstructions = decompressor(strings)
# Out:
# String representation of first digit in hexadecimal: 0x865d6a8ff1d1d1f9c4b740
# Number of bits actually needed to represent it: 84.89

# %%
#len(strings[0].numpy())
print((128*1024)/(sum([len(s.numpy()) for s in strings])/4))
# Out:
# 384.0937728937729

# %%
def get_memory_size(tf_array):

  # Convert the tensor to a NumPy array
  my_array = tf_array.numpy()

  # Get the memory size in bytes
  memory_size_mb = my_array.nbytes / (1024 * 1024)

  # Print the memory size
  print("Memory Size:", memory_size_mb, "MB")

  return memory_size_mb

origi_size_mb = get_memory_size(originals)
compr_size_mb = get_memory_size(strings)

print(origi_size_mb / compr_size_mb)
# Out:
# Memory Size: 0.5 MB
# Memory Size: 0.0009765625 MB
# 512.0

# %%
def display_patch(originals, strings, entropies, reconstructions):
  """Visualizes 16 digits together with their reconstructions."""
  fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(12, 6))
  axes = axes.ravel()
  for i in range(len(axes)):
    image = tf.concat([   
        tf.squeeze(originals[i]),                                # original
        tf.zeros((originals[i].shape[1], 1), tf.float32) - 255,  # boundary 
        tf.squeeze(reconstructions[i]),                          # reconstruction
        tf.zeros((originals[i].shape[1], 1), tf.float32) - 255,  # boundary
        tf.squeeze(originals[i] - reconstructions[i])            # original - reconstruction
        ], 1)
    
    pclip = np.percentile(originals, 99.)
    axes[i].imshow(image, cmap='seismic', vmin=-pclip, vmax=pclip)

    txt = f"{entropies[i]:0.2f} bits"
    # axes[i].set_title(txt)
    # axes[i].axis("off")
    
  plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
  plt.tight_layout()
  plt.savefig('Patch.png', dpi=300, pad_inches=0.1)

# %%
# 4 x 4 plots, for each: (original, reconstruction, original - reconstruction)
display_patch(originals, strings, entropies, reconstructions)

# %% [markdown]
# ## Test the reconstruction for whole DAS section

# %%
# Load the original data just from one file
pdata = np.load(file_test[0])['pdata']
patches, factors = extract_image_patches(pdata, patch_size)
patches_original = tf.convert_to_tensor(patches, dtype=tf.float32)

# %%
# Compress them to strings, and keep track of each of their information content in bits.
strings, entropies = compressor(patches_original)

print(f"String representation of first digit in hexadecimal: 0x{strings[0].numpy().hex()}")
print(f"Number of bits actually needed to represent it: {entropies[0]:0.2f}")

# Decompress the images back from the strings.
patches_decompre = decompressor(strings)
# Out:
# String representation of first digit in hexadecimal: 0xd85f3d189092b226bae3bf
# Number of bits actually needed to represent it: 82.65

# %%
# Compare the size in Mb
origi_size_mb = get_memory_size(patches_original)
compr_size_mb = get_memory_size(strings)
decompr_size_mb = get_memory_size(patches_decompre)

print(origi_size_mb / compr_size_mb)
# Out:
# Memory Size: 54.4921875 MB
# Memory Size: 0.1064300537109375 MB
# Memory Size: 54.4921875 MB
# 512.0

# %%
# Load the original data just from one file
# Warning: this data has been used in training!! 
# We need to benchmark other data not used in training later.
original_shape = pdata.shape
print('shape of original data: ', original_shape)

original_das = reconstruct_image_from_patches(patches_original, factors, original_shape, patch_size)
decompre_das = reconstruct_image_from_patches(patches_decompre, factors, original_shape, patch_size)
# Out:
# shape of original data:  (4800, 3000)

# %%
plt.figure(figsize=(12, 9))
plt.rcParams.update({'font.size': 12})
from mpl_toolkits.axes_grid1 import make_axes_locatable


nt = 2500
nc = 3000
aspect = 0.22

relloss = np.sum(np.abs(original_das - decompre_das))/np.sum(np.abs(original_das))
print
plt.subplot(311)
pclip = np.percentile(original_das, 99.)
plt.imshow(original_das[:nc, :nt], cmap='gray', aspect=aspect, vmin=-pclip, vmax=pclip)
# plt.xlabel('#Time samples')
plt.ylabel('#Channels')
# plt.title('Original DAS')
# plt.colorbar(orientation="horizontal",fraction=0.07)
plt.colorbar(shrink=0.75)

plt.subplot(312)
plt.imshow(decompre_das[:nc, :nt], cmap='gray', aspect=aspect, vmin=-pclip, vmax=pclip)
# plt.xlabel('#Time samples')
plt.ylabel('#Channels')
# plt.title('Reconstructed DAS')
# plt.colorbar(orientation="horizontal",fraction=0.07)
plt.colorbar(shrink=0.75)

plt.subplot(313)
plt.imshow(original_das[:nc, :nt] - decompre_das[:nc, :nt], cmap='gray', aspect=aspect, vmin=-pclip, vmax=pclip)
plt.xlabel('#Time samples')
plt.ylabel('#Channels')
# plt.title('Difference')
# plt.colorbar(orientation="horizontal",fraction=0.07)
plt.colorbar(shrink=0.75)

plt.tight_layout()
plt.savefig('./drive/MyDrive/Training Dataset/Final-DAS.png', dpi=300, pad_inches=0.1)

# %%
# Save the compressed data for stand-alone test
np.save('./drive/MyDrive/Training Dataset/original_das', original_das)
np.save('./drive/MyDrive/Training Dataset/decompre_das', decompre_das)
np.save('./drive/MyDrive/Training Dataset/strings.npy', strings.numpy())
np.save('./drive/MyDrive/Training Dataset/entropies.npy', entropies.numpy())
np.save('./drive/MyDrive/Training Dataset/patches_original.npy', patches_original.numpy())
np.save('./drive/MyDrive/Training Dataset/factors.npy', factors)
